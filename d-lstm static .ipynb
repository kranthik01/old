# %%
import numpy as np
import pandas as pd
import sklearn
import tensorflow as tf
import matplotlib.pyplot as plt

# Check for TensorFlow GPU access
print(f"TensorFlow has access to the following devices:\n{tf.config.list_physical_devices()}")

# See TensorFlow version
print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow has access to the following devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow version: 2.8.0

# %%
# d-lstm static 
import numpy as np
import random as rn
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()



import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
rn.seed(12345)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K
tf.set_random_seed(1234)

sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import LSTM
from deap import base, creator, tools, algorithms
from keras import regularizers
from math import sqrt
from matplotlib import pyplot
import matplotlib.pyplot as plt
import numpy as np
from numpy import concatenate
import random


def parser(x):
	return datetime.strptime(x, '%Y%m')

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# scale train and test data to [-1, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled

# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
	new_row = [x for x in X] + [value]
	array = np.array(new_row)
	array = array.reshape(1, len(array))
	inverted = scaler.inverse_transform(array)
	return inverted[0, -1]

# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
	X, y = train[:, 0:-1], train[:, -1]
	X = X.reshape(X.shape[0], X.shape[1],1 )
	
	model = Sequential()
	model.add(LSTM(neurons[0], batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
	model.add(Dropout(0.3))
	#model.add(LSTM(neurons[1], batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
	#model.add(Dropout(0.3))
	#model.add(LSTM(neurons[2], batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
	#model.add(Dropout(0.3))
	# model.add(LSTM(neurons[3], batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
	# model.add(Dropout(0.3))
	model.add(Dense(1))
	model.compile(loss='mean_squared_error', optimizer='adam')
	
	for i in range(nb_epoch):
		print('Epoch:',i)
		model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
		model.reset_states()
	
	return model
	


# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, len(X), 1)
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataset = np.insert(dataset,[0]*look_back,0)    
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back)]
		dataX.append(a)
		dataY.append(dataset[i + look_back])
	dataY= np.array(dataY)        
	dataY = np.reshape(dataY,(dataY.shape[0],1))
	dataset = np.concatenate((dataX,dataY),axis=1)  
	return dataset


# compute RMSPE
def RMSPE(x,y):
	result=0
	for i in range(len(x)):
		result += ((x[i]-y[i])/x[i])**2
	result /= len(x)
	result = sqrt(result)
	result *= 100
	return result

# compute MAPE
def MAPE(x,y):
	result=0
	for i in range(len(x)):
		result += abs((x[i]-y[i])/x[i])
	result /= len(x)
	result *= 100
	return result




def experiment(series,look_back,neurons,n_epoch):



	#load dataset
	series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
	raw_values = series.values
	# transform data to be stationary
	diff = difference(raw_values, 1)
	

	# create dataset x,y
	dataset = diff.values
	dataset = create_dataset(dataset,look_back)


	# split into train and test sets
	train_size = int(dataset.shape[0] * 0.8)
	test_size = dataset.shape[0] - train_size
	train, test = dataset[0:train_size], dataset[train_size:]


	# transform the scale of the data
	scaler, train_scaled, test_scaled = scale(train, test)

	
	
	# fit the model
	lstm_model = fit_lstm(train_scaled, 1, n_epoch, neurons)
	

	# forecast the entire training dataset to build up state for forecasting
	print('Forecasting Training Data')   
	predictions_train = list()
	for i in range(len(train_scaled)):
		# make one-step forecast
		X, y = train_scaled[i, 0:-1], train_scaled[i, -1]
		yhat = forecast_lstm(lstm_model, 1, X)
		# invert scaling
		yhat = invert_scale(scaler, X, yhat)
		# invert differencing
		yhat = inverse_difference(raw_values, yhat, len(raw_values)-i)
		# store forecast
		predictions_train.append(yhat)
		expected = raw_values[ i+1 ] 
		print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))

	# report performance
	rmse_train = sqrt(mean_squared_error(raw_values[1:len(train_scaled)+1], predictions_train))
	print('Train RMSE: %.5f' % rmse_train)
	#report performance using RMSPE
	RMSPE_train = RMSPE(raw_values[1:len(train_scaled)+1],predictions_train)
	print('Train RMSPE: %.5f' % RMSPE_train)
	MAE_train = mean_absolute_error(raw_values[1:len(train_scaled)+1], predictions_train)
	print('Train MAE: %.5f' % MAE_train)
	MAPE_train = MAPE(raw_values[1:len(train_scaled)+1], predictions_train)
	print('Train MAPE: %.5f' % MAPE_train)

	# forecast the test data
	print('Forecasting Testing Data')
	predictions_test = list()
	for i in range(len(test_scaled)):
		# make one-step forecast
		X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
		yhat = forecast_lstm(lstm_model, 1, X)
		# invert scaling
		yhat = invert_scale(scaler, X, yhat)
		# invert differencing
		yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
		# store forecast
		predictions_test.append(yhat)
		expected = raw_values[len(train) + i + 1]
		print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))

	# report performance using RMSE
	rmse_test = sqrt(mean_squared_error(raw_values[-len(test_scaled):], predictions_test))
	print('Test RMSE: %.5f' % rmse_test)
	#report performance using RMSPE
	RMSPE_test = RMSPE(raw_values[-len(test_scaled):], predictions_test)
	print('Test RMSPE: %.5f' % RMSPE_test)
	MAE_test = mean_absolute_error(raw_values[-len(test_scaled):], predictions_test)
	print('Test MAE: %.5f' % MAE_test)
	MAPE_test = MAPE(raw_values[-len(test_scaled):], predictions_test)
	print('Test MAPE: %.5f' % MAPE_test)

	predictions = np.concatenate((predictions_train,predictions_test),axis=0)

	# line plot of observed vs predicted
	fig, ax = plt.subplots(1)
	ax.plot(raw_values, label='original', color='blue')
	ax.plot(predictions, label='predictions', color='red')
	ax.axvline(x=len(train_scaled)+1,color='k', linestyle='--')
	ax.legend(loc='upper right')
	ax.set_xlabel('Time',fontsize = 16)
	ax.set_ylabel('oil production '+ r'$(10^4 m^3)$',fontsize = 16)
	plt.show()


def run():

	#load dataset
	series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
	look_back=5
	neurons= [ 5 , 4, 2] 
	n_epochs=800
	
	

	experiment(series,look_back,neurons,n_epochs)


run()
# Out:
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch: 0
# Train on 180 samples
# 2022-04-20 01:41:14.291185: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# /var/folders/pb/zjk7bcqn4l73lc2cmv6y5_gh0000gn/T/ipykernel_9162/4164730389.py:26: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# 2022-04-20 01:41:14.291258: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /var/folders/pb/zjk7bcqn4l73lc2cmv6y5_gh0000gn/T/ipykernel_9162/4164730389.py:248: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
# /var/folders/pb/zjk7bcqn4l73lc2cmv6y5_gh0000gn/T/ipykernel_9162/4164730389.py:152: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
# 2022-04-20 01:41:14.502068: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-04-20 01:41:14.503301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-20 01:41:14.554547: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#   1/180 [..............................] - ETA: 1:20 - loss: 0.1860
# 2022-04-20 01:41:14.733713: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0506
# Epoch: 1
# Train on 180 samples
#   9/180 [>.............................] - ETA: 2s - loss: 0.0585
# 2022-04-20 01:41:17.429769: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-20 01:41:17.449874: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0448
# Epoch: 2
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0420
# Epoch: 3
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0395
# Epoch: 4
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0373
# Epoch: 5
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0353
# Epoch: 6
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0338
# Epoch: 7
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0327
# Epoch: 8
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0319
# Epoch: 9
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0314
# Epoch: 10
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0310
# Epoch: 11
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0307
# Epoch: 12
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0305
# Epoch: 13
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0302
# Epoch: 14
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0300
# Epoch: 15
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0297
# Epoch: 16
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0295
# Epoch: 17
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0293
# Epoch: 18
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0291
# Epoch: 19
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0289
# Epoch: 20
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0287
# Epoch: 21
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0284
# Epoch: 22
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0282
# Epoch: 23
# Train on 180 samples
# 180/180 [==============================] - 3s 15ms/sample - loss: 0.0281
# Epoch: 24
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0279
# Epoch: 25
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0277
# Epoch: 26
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0276
# Epoch: 27
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0274
# Epoch:
# Train on 180 samples
# 180/180 [==============================] - 3s 15ms/sample - loss: 0.0160
# Epoch: 411
# Train on 180 samples
# 180/180 [==============================] - 3s 15ms/sample - loss: 0.0160
# Epoch: 412
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0160
# Epoch: 413
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0160
# Epoch: 414
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0160
# Epoch: 415
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0160
# Epoch: 416
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0159
# Epoch: 417
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0159
# Epoch: 418
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0159
# Epoch: 419
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0159
# Epoch: 420
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0159
# Epoch: 421
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0159
# Epoch: 422
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 423
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 424
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 425
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 426
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 427
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 428
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 429
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 430
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0158
# Epoch: 431
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0157
# Epoch: 432
# Train on 180 samples
# ...
# Epoch: 758
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 759
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 760
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 761
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 762
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 763
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 764
# Train on 180 samples
# 180/180 [==============================] - 3s 15ms/sample - loss: 0.0148
# Epoch: 765
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 766
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 767
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 768
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 769
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0148
# Epoch: 770
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 771
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 772
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 773
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 774
# Train on 180 samples
# 180/180 [==============================] - 3s 15ms/sample - loss: 0.0147
# Epoch: 775
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 776
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 777
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 778
# Train on 180 samples
# 180/180 [==============================] - 3s 15ms/sample - loss: 0.0147
# Epoch: 779
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 780
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 781
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 782
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 783
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0147
# Epoch: 784
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0147
# Epoch: 785
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0147
# Epoch: 786
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0147
# Epoch: 787
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0147
# Epoch: 788
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0147
# Epoch: 789
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0147
# Epoch: 790
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0147
# Epoch: 791
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 792
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 793
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 794
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 795
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 796
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 797
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 798
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Epoch: 799
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0146
# Forecasting Training Data
# /Users/chaitanya_kr_01/tensorflow-test/env/lib/python3.8/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2022-04-20 02:14:50.359072: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Month=1, Predicted=10.325975, Expected=9.510000
# Month=2, Predicted=9.897741, Expected=9.796000
# Month=3, Predicted=9.876330, Expected=9.468500
# Month=4, Predicted=9.324552, Expected=9.672000
# Month=5, Predicted=10.014364, Expected=9.610000
# Month=6, Predicted=9.316310, Expected=9.240000
# Month=7, Predicted=9.735482, Expected=10.318300
# Month=8, Predicted=9.868393, Expected=8.974800
# Month=9, Predicted=9.485420, Expected=9.114000
# Month=10, Predicted=9.237893, Expected=9.300000
# Month=11, Predicted=8.987995, Expected=8.400000
# Month=12, Predicted=9.068134, Expected=9.300000
# Month=13, Predicted=9.068177, Expected=9.000000
# Month=14, Predicted=8.982810, Expected=9.300000
# Month=15, Predicted=9.323410, Expected=9.460000
# Month=16, Predicted=9.355123, Expected=9.145000
# Month=17, Predicted=9.137796, Expected=9.021000
# Month=18, Predicted=8.999964, Expected=8.750000
# Month=19, Predicted=8.787206, Expected=8.710000
# Month=20, Predicted=8.641856, Expected=8.370000
# Month=21, Predicted=8.469695, Expected=8.504000
# Month=22, Predicted=8.757315, Expected=9.819700
# Month=23, Predicted=9.018161, Expected=9.827300
# Month=24, Predicted=9.914827, Expected=9.929800
# Month=25, Predicted=9.760037, Expected=9.288000
# Month=26, Predicted=9.312998, Expected=9.300000
# Month=27, Predicted=9.139392, Expected=9.060000
# Month=28, Predicted=8.902449, Expected=8.835000
# Month=29, Predicted=8.730048, Expected=8.388600
# Month=30, Predicted=8.706158, Expected=8.400000
# Month=31, Predicted=8.664300, Expected=8.525000
# Month=32, Predicted=8.290298, Expected=8.250000
# Month=33, Predicted=8.715787, Expected=8.419000
# Month=34, Predicted=8.513826, Expected=9.455000
# Month=35, Predicted=8.824953, Expected=8.540000
# Month=36, Predicted=9.025178, Expected=9.455000
# Month=37, Predicted=9.069265, Expected=9.000000
# Month=38, Predicted=9.198881, Expected=9.599000
# Month=39, Predicted=9.343462, Expected=9.436000
# Month=40, Predicted=9.325707, Expected=9.539800
# Month=41, Predicted=9.391388, Expected=9.028600
# Month=42, Predicted=8.921024, Expected=8.932000
# Month=43, Predicted=8.853707, Expected=8.993000
# Month=44, Predicted=8.851780, Expected=8.678400
# Month=45, Predicted=8.652925, Expected=9.011100
# Month=46, Predicted=9.259870, Expected=9.630000
# Month=47, Predicted=9.002731, Expected=8.590400
# Month=48, Predicted=9.364648, Expected=9.736300
# Month=49, Predicted=9.396321, Expected=9.384500
# Month=50, Predicted=9.847084, Expected=9.947200
# Month=51, Predicted=9.686380, Expected=9.577100
# Month=52, Predicted=9.539791, Expected=9.117200
# Month=53, Predicted=8.980414, Expected=9.122500
# Month=54, Predicted=9.000122, Expected=8.880000
# Month=55, Predicted=8.791014, Expected=8.709200
# Month=56, Predicted=8.278852, Expected=8.428200
# Month=57, Predicted=9.377645, Expected=9.907600
# Month=58, Predicted=9.535672, Expected=9.145000
# Month=59, Predicted=9.051087, Expected=8.498000
# Month=60, Predicted=9.001503, Expected=9.362000
# Month=61, Predicted=8.927919, Expected=9.000000
# Month=62, Predicted=9.203091, Expected=9.455000
# Month=63, Predicted=9.335343, Expected=9.300000
# Month=64, Predicted=9.255572, Expected=8.990000
# Month=65, Predicted=8.999132, Expected=8.990000
# Month=66, Predicted=8.986016, Expected=8.790000
# Month=67, Predicted=8.844846, Expected=8.835000
# Month=68, Predicted=8.871933, Expected=8.700000
# Month=69, Predicted=8.638760, Expected=8.935000
# Month=70, Predicted=9.043946, Expected=8.835000
# Month=71, Predicted=8.784952, Expected=8.265000
# Month=72, Predicted=8.687571, Expected=8.835000
# Month=73, Predicted=8.655332, Expected=8.550000
# Month=74, Predicted=8.645913, Expected=8.680000
# Month=75, Predicted=8.864825, Expected=8.400000
# Month=76, Predicted=8.400536, Expected=8.525000
# Month=77, Predicted=8.549141, Expected=8.370000
# Month=78, Predicted=8.346010, Expected=7.890000
# Month=79, Predicted=8.328439, Expected=7.812000
# Month=80, Predicted=7.937249, Expected=7.620000
# Month=81, Predicted=7.717413, Expected=7.718000
# Month=82, Predicted=7.946542, Expected=8.323500
# Month=83, Predicted=7.794730, Expected=6.860000
# Month=84, Predicted=7.620392, Expected=8.308000
# Month=85, Predicted=8.018881, Expected=8.100000
# Month=86, Predicted=8.493958, Expected=8.525000
# Month=87, Predicted=8.347127, Expected=8.250000
# Month=88, Predicted=8.252708, Expected=8.215000
# Month=89, Predicted=8.043580, Expected=8.122600
# Month=90, Predicted=7.994208, Expected=7.778100
# Month=91, Predicted=7.700172, Expected=7.954600
# Month=92, Predicted=7.824604, Expected=7.420000
# Month=93, Predicted=7.399636, Expected=7.538300
# Month=94, Predicted=7.962747, Expected=7.905000
# Month=95, Predicted=7.220859, Expected=7.140000
# Month=96, Predicted=7.964585, Expected=8.432000
# Month=97, Predicted=8.086473, Expected=7.710000
# Month=98, Predicted=8.181558, Expected=7.967000
# Month=99, Predicted=7.846573, Expected=7.320000
# Month=100, Predicted=7.456461, Expected=7.502000
# Month=101, Predicted=7.418617, Expected=7.409000
# Month=102, Predicted=7.141261, Expected=7.200600
# Month=103, Predicted=7.696048, Expected=7.865000
# Month=104, Predicted=7.470979, Expected=6.690000
# Month=105, Predicted=7.244386, Expected=6.879400
# Month=106, Predicted=7.096357, Expected=7.440000
# Month=107, Predicted=6.795744, Expected=6.860000
# Month=108, Predicted=7.528824, Expected=7.595000
# Month=109, Predicted=7.313747, Expected=7.200000
# Month=110, Predicted=7.586715, Expected=7.130000
# Month=111, Predicted=7.045678, Expected=6.900000
# Month=112, Predicted=6.956789, Expected=7.130000
# Month=113, Predicted=7.027681, Expected=7.130000
# Month=114, Predicted=6.921656, Expected=6.840000
# Month=115, Predicted=7.176203, Expected=7.006000
# Month=116, Predicted=6.966214, Expected=6.780000
# Month=117, Predicted=6.913252, Expected=7.089600
# Month=118, Predicted=7.062153, Expected=6.882000
# Month=119, Predicted=6.842295, Expected=6.446700
# Month=120, Predicted=6.797216, Expected=6.882000
# Month=121, Predicted=6.692871, Expected=6.600000
# Month=122, Predicted=6.734473, Expected=6.820000
# Month=123, Predicted=6.955954, Expected=6.600000
# Month=124, Predicted=6.540006, Expected=6.820000
# Month=125, Predicted=6.807795, Expected=6.665000
# Month=126, Predicted=6.682306, Expected=6.450000
# Month=127, Predicted=6.620001, Expected=6.665000
# Month=128, Predicted=6.545304, Expected=6.450000
# Month=129, Predicted=6.573045, Expected=6.722100
# Month=130, Predicted=6.725423, Expected=6.820000
# Month=131, Predicted=6.645818, Expected=6.160000
# Month=132, Predicted=6.473472, Expected=6.820000
# Month=133, Predicted=6.584837, Expected=6.480000
# Month=134, Predicted=6.724065, Expected=6.596900
# Month=135, Predicted=6.612507, Expected=6.492000
# Month=136, Predicted=6.430500, Expected=6.510000
# Month=137, Predicted=6.535602, Expected=6.339500
# Month=138, Predicted=6.372694, Expected=6.001600
# Month=139, Predicted=6.261322, Expected=6.107000
# Month=140, Predicted=6.119373, Expected=5.790000
# Month=141, Predicted=5.936341, Expected=5.885000
# Month=142, Predicted=6.166575, Expected=7.280000
# Month=143, Predicted=6.481869, Expected=5.941600
# Month=144, Predicted=6.540566, Expected=6.810000
# Month=145, Predicted=6.490555, Expected=6.182000
# Month=146, Predicted=6.367997, Expected=6.293000
# Month=147, Predicted=6.187520, Expected=6.118600
# Month=148, Predicted=6.046172, Expected=6.138000
# Month=149, Predicted=6.064225, Expected=6.107000
# Month=150, Predicted=6.018864, Expected=5.913000
# Month=151, Predicted=6.022292, Expected=6.141100
# Month=152, Predicted=6.067830, Expected=6.248000
# Month=153, Predicted=6.145098, Expected=5.829700
# Month=154, Predicted=6.130121, Expected=6.829300
# Month=155, Predicted=6.430269, Expected=6.694400
# Month=156, Predicted=6.880945, Expected=7.726200
# Month=157, Predicted=7.333712, Expected=7.054400
# Month=158, Predicted=7.153396, Expected=7.268900
# Month=159, Predicted=7.021475, Expected=7.020000
# Month=160, Predicted=6.924055, Expected=6.510000
# Month=161, Predicted=6.409283, Expected=6.370500
# Month=162, Predicted=6.173087, Expected=5.730000
# Month=163, Predicted=5.653581, Expected=5.828000
# Month=164, Predicted=5.692514, Expected=5.580000
# Month=165, Predicted=5.698751, Expected=5.709900
# Month=166, Predicted=6.499283, Expected=6.696000
# Month=167, Predicted=6.366510, Expected=6.248000
# Month=168, Predicted=6.482856, Expected=6.711600
# Month=169, Predicted=6.965155, Expected=6.600100
# Month=170, Predicted=6.707319, Expected=7.508200
# Month=171, Predicted=7.141751, Expected=7.765000
# Month=172, Predicted=7.651351, Expected=7.285000
# Month=173, Predicted=7.219044, Expected=6.959500
# Month=174, Predicted=6.860456, Expected=6.450000
# Month=175, Predicted=6.410119, Expected=6.572000
# Month=176, Predicted=6.426137, Expected=6.600000
# Month=177, Predicted=5.000761, Expected=4.265300
# Month=178, Predicted=6.421827, Expected=7.367000
# Month=179, Predicted=6.789311, Expected=6.544000
# Month=180, Predicted=6.781107, Expected=6.940800
# Train RMSE: 0.35059
# Train RMSPE: 4.61601
# Train MAE: 0.26436
# Train MAPE: 3.44386
# Forecasting Testing Data
# Month=1, Predicted=6.926437, Expected=6.786000
# Month=2, Predicted=6.750603, Expected=6.981200
# Month=3, Predicted=6.852619, Expected=6.756000
# Month=4, Predicted=6.712408, Expected=6.733200
# Month=5, Predicted=6.671944, Expected=6.671200
# Month=6, Predicted=6.644172, Expected=6.295600
# Month=7, Predicted=6.358610, Expected=6.432500
# Month=8, Predicted=6.400937, Expected=6.153000
# Month=9, Predicted=6.162458, Expected=6.389500
# Month=10, Predicted=6.600272, Expected=7.192000
# Month=11, Predicted=6.485273, Expected=6.524000
# Month=12, Predicted=6.978086, Expected=7.238500
# Month=13, Predicted=6.912125, Expected=6.990000
# Month=14, Predicted=7.183233, Expected=7.254000
# Month=15, Predicted=7.069090, Expected=6.720000
# Month=16, Predicted=6.632318, Expected=6.944000
# Month=17, Predicted=6.821178, Expected=7.052500
# Month=18, Predicted=6.922764, Expected=6.690000
# Month=19, Predicted=6.670973, Expected=6.909900
# Month=20, Predicted=6.791716, Expected=6.819000
# Month=21, Predicted=6.831432, Expected=7.167200
# Month=22, Predicted=6.956815, Expected=7.254000
# Month=23, Predicted=7.132668, Expected=6.664000
# Month=24, Predicted=6.797405, Expected=7.393500
# Month=25, Predicted=7.091945, Expected=7.125000
# Month=26, Predicted=7.232772, Expected=7.347000
# Month=27, Predicted=7.237422, Expected=7.216500
# Month=28, Predicted=7.187632, Expected=7.254000
# Month=29, Predicted=7.156719, Expected=7.238500
# Month=30, Predicted=7.163923, Expected=6.990000
# Month=31, Predicted=6.973227, Expected=7.192000
# Month=32, Predicted=7.089514, Expected=6.900000
# Month=33, Predicted=6.914929, Expected=7.427300
# Month=34, Predicted=7.241036, Expected=7.300500
# Month=35, Predicted=7.210939, Expected=6.902000
# Month=36, Predicted=7.094786, Expected=7.409000
# Month=37, Predicted=7.190318, Expected=7.179000
# Month=38, Predicted=7.321664, Expected=7.424500
# Month=39, Predicted=7.290249, Expected=7.275000
# Month=40, Predicted=7.291458, Expected=7.316000
# Month=41, Predicted=7.273054, Expected=7.086300
# Month=42, Predicted=7.146544, Expected=7.020000
# Month=43, Predicted=7.034706, Expected=7.270500
# Month=44, Predicted=7.059403, Expected=7.168800
# Month=45, Predicted=7.264093, Expected=7.448600
# Month=46, Predicted=7.387731, Expected=7.440200
# Test RMSE: 0.24139
# Test RMSPE: 3.43425
# Test MAE: 0.18821
# Test MAPE: 2.68726

# %%
# oil static.py bi lstm 


import numpy as np
import random as rn
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()


import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
rn.seed(12345)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K
tf.set_random_seed(1234)

sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)
from pandas import DataFrame
from pandas import Series
from pandas import concat
from pandas import read_csv
from pandas import datetime
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
#from deap import base, creator, tools, algorithms
from keras import regularizers
from math import sqrt
from matplotlib import pyplot
import matplotlib.pyplot as plt
import numpy as np
from numpy import concatenate
import random


def parser(x):
	return datetime.strptime(x, '%Y%m')

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# scale train and test data to [-1, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)
	# transform train
	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)
	# transform test
	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled

# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
	new_row = [x for x in X] + [value]
	array = np.array(new_row)
	array = array.reshape(1, len(array))
	inverted = scaler.inverse_transform(array)
	return inverted[0, -1]

# fit an LSTM network to training data
def fit_lstm(train, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], X.shape[1],1 )
    model = Sequential()
    model.add(Bidirectional(LSTM(64, activation='swish')))
    model.add(Dense(1))
    # Compile the model
    model.compile(optimizer='adam', loss='mse')
    for i in range(nb_epoch):
        print('Epoch:',i)
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=1, shuffle=False)
        model.reset_states()

    return model



# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, len(X), 1)
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataset = np.insert(dataset,[0]*look_back,0)    
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back):
		a = dataset[i:(i+look_back)]
		dataX.append(a)
		dataY.append(dataset[i + look_back])
	dataY= np.array(dataY)        
	dataY = np.reshape(dataY,(dataY.shape[0],1))
	dataset = np.concatenate((dataX,dataY),axis=1)  
	return dataset


# compute RMSPE
def RMSPE(x,y):
	result=0
	for i in range(len(x)):
		result += ((x[i]-y[i])/x[i])**2
	result /= len(x)
	result = sqrt(result)
	result *= 100
	return result

# compute MAPE
def MAPE(x,y):
	result=0
	for i in range(len(x)):
		result += abs((x[i]-y[i])/x[i])
	result /= len(x)
	result *= 100
	return result




def experiment(series,look_back,neurons,n_epoch):



	#load dataset
	series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
	raw_values = series.values
	# transform data to be stationary
	diff = difference(raw_values, 1)
	

	# create dataset x,y
	dataset = diff.values
	dataset = create_dataset(dataset,look_back)


	# split into train and test sets
	train_size = int(dataset.shape[0] * 0.8)
	test_size = dataset.shape[0] - train_size
	train, test = dataset[0:train_size], dataset[train_size:]


	# transform the scale of the data
	scaler, train_scaled, test_scaled = scale(train, test)

	
	
	# fit the model
	lstm_model = fit_lstm(train_scaled, 1, n_epoch, neurons)
	

	# forecast the entire training dataset to build up state for forecasting
	print('Forecasting Training Data')   
	predictions_train = list()
	for i in range(len(train_scaled)):
		# make one-step forecast
		X, y = train_scaled[i, 0:-1], train_scaled[i, -1]
		yhat = forecast_lstm(lstm_model, 1, X)
		# invert scaling
		yhat = invert_scale(scaler, X, yhat)
		# invert differencing
		yhat = inverse_difference(raw_values, yhat, len(raw_values)-i)
		# store forecast
		predictions_train.append(yhat)
		expected = raw_values[ i+1 ] 
		print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))

	# report performance
	rmse_train = sqrt(mean_squared_error(raw_values[1:len(train_scaled)+1], predictions_train))
	print('Train RMSE: %.5f' % rmse_train)
	#report performance using RMSPE
	RMSPE_train = RMSPE(raw_values[1:len(train_scaled)+1],predictions_train)
	print('Train RMSPE: %.5f' % RMSPE_train)
	MAE_train = mean_absolute_error(raw_values[1:len(train_scaled)+1], predictions_train)
	print('Train MAE: %.5f' % MAE_train)
	MAPE_train = MAPE(raw_values[1:len(train_scaled)+1], predictions_train)
	print('Train MAPE: %.5f' % MAPE_train)

	# forecast the test data
	print('Forecasting Testing Data')
	predictions_test = list()
	for i in range(len(test_scaled)):
		# make one-step forecast
		X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
		yhat = forecast_lstm(lstm_model, 1, X)
		# invert scaling
		yhat = invert_scale(scaler, X, yhat)
		# invert differencing
		yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
		# store forecast
		predictions_test.append(yhat)
		expected = raw_values[len(train) + i + 1]
		print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))

	# report performance using RMSE
	rmse_test = sqrt(mean_squared_error(raw_values[-len(test_scaled):], predictions_test))
	print('Test RMSE: %.5f' % rmse_test)
	#report performance using RMSPE
	RMSPE_test = RMSPE(raw_values[-len(test_scaled):], predictions_test)
	print('Test RMSPE: %.5f' % RMSPE_test)
	MAE_test = mean_absolute_error(raw_values[-len(test_scaled):], predictions_test)
	print('Test MAE: %.5f' % MAE_test)
	MAPE_test = MAPE(raw_values[-len(test_scaled):], predictions_test)
	print('Test MAPE: %.5f' % MAPE_test)

	predictions = np.concatenate((predictions_train,predictions_test),axis=0)

	# line plot of observed vs predicted
	fig, ax = plt.subplots(1)
	ax.plot(raw_values, label='original', color='blue')
	ax.plot(predictions, label='predictions', color='red')
	ax.axvline(x=len(train_scaled)+1,color='k', linestyle='--')
	ax.legend(loc='upper right')
	ax.set_xlabel('Time',fontsize = 16)
	ax.set_ylabel('oil production '+ r'$(10^4 m^3)$',fontsize = 16)
	plt.show()


def run():

	#load dataset
	series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
	look_back=2
	neurons=[7,6,5,4,2] 
	n_epochs=1200
	
	

	experiment(series,look_back,neurons,n_epochs)


run()
# Out:
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:From /Users/chaitanya_kr_01/tensorflow-test/env/lib/python3.8/site-packages/tensorflow/python/ops/init_ops.py:93: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/chaitanya_kr_01/tensorflow-test/env/lib/python3.8/site-packages/tensorflow/python/ops/init_ops.py:93: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/chaitanya_kr_01/tensorflow-test/env/lib/python3.8/site-packages/tensorflow/python/ops/init_ops.py:93: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-04-20 02:18:11.739202: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-04-20 02:18:11.740208: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /var/folders/pb/zjk7bcqn4l73lc2cmv6y5_gh0000gn/T/ipykernel_9162/1083862738.py:27: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime
# /var/folders/pb/zjk7bcqn4l73lc2cmv6y5_gh0000gn/T/ipykernel_9162/1083862738.py:242: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
# /var/folders/pb/zjk7bcqn4l73lc2cmv6y5_gh0000gn/T/ipykernel_9162/1083862738.py:146: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_csv('oil_production.csv', header=0,parse_dates=[0],index_col=0, squeeze=True,date_parser=parser)
# Epoch: 0
# Train on 180 samples
# 2022-04-20 02:18:12.261281: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-20 02:18:12.317819: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-20 02:18:12.390640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0529
# Epoch: 1
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0470
# Epoch: 2
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0443
# Epoch: 3
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0406
# Epoch: 4
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0365
# Epoch: 5
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0338
# Epoch: 6
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0326
# Epoch: 7
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0321
# Epoch: 8
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0317
# Epoch: 9
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0314
# Epoch: 10
# Train on 180 samples
# 180/180 [==============================] - 2s 13ms/sample - loss: 0.0312
# Epoch: 11
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0309
# Epoch: 12
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0307
# Epoch: 13
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0305
# Epoch: 14
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0304
# Epoch: 15
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0303
# Epoch: 16
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0301
# Epoch: 17
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0300
# Epoch: 18
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0299
# Epoch: 19
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0231
# Epoch: 1187
# Train on 180 samples
# 180/180 [==============================] - 3s 18ms/sample - loss: 0.0232
# Epoch: 1188
# Train on 180 samples
# 180/180 [==============================] - 3s 17ms/sample - loss: 0.0231
# Epoch: 1189
# Train on 180 samples
# 180/180 [==============================] - 3s 17ms/sample - loss: 0.0232
# Epoch: 1190
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0231
# Epoch: 1191
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0232
# Epoch: 1192
# Train on 180 samples
# 180/180 [==============================] - 3s 16ms/sample - loss: 0.0231
# Epoch: 1193
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0231
# Epoch: 1194
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0231
# Epoch: 1195
# Train on 180 samples
# 180/180 [==============================] - 3s 14ms/sample - loss: 0.0231
# Epoch: 1196
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0231
# Epoch: 1197
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0231
# Epoch: 1198
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0231
# Epoch: 1199
# Train on 180 samples
# 180/180 [==============================] - 2s 14ms/sample - loss: 0.0231
# Forecasting Training Data
# /Users/chaitanya_kr_01/tensorflow-test/env/lib/python3.8/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2022-04-20 03:07:41.297155: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Month=1, Predicted=10.116478, Expected=9.510000
# Month=2, Predicted=10.092515, Expected=9.796000
# Month=3, Predicted=9.647469, Expected=9.468500
# Month=4, Predicted=9.631820, Expected=9.672000
# Month=5, Predicted=9.673723, Expected=9.610000
# Month=6, Predicted=9.314907, Expected=9.240000
# Month=7, Predicted=9.392967, Expected=10.318300
# Month=8, Predicted=9.689970, Expected=8.974800
# Month=9, Predicted=9.494219, Expected=9.114000
# Month=10, Predicted=9.273465, Expected=9.300000
# Month=11, Predicted=8.740874, Expected=8.400000
# Month=12, Predicted=9.370292, Expected=9.300000
# Month=13, Predicted=8.803525, Expected=9.000000
# Month=14, Predicted=9.415373, Expected=9.300000
# Month=15, Predicted=9.261841, Expected=9.460000
# Month=16, Predicted=8.845864, Expected=9.145000
# Month=17, Predicted=9.211511, Expected=9.021000
# Month=18, Predicted=9.107383, Expected=8.750000
# Month=19, Predicted=8.845118, Expected=8.710000
# Month=20, Predicted=8.769134, Expected=8.370000
# Month=21, Predicted=8.495377, Expected=8.504000
# Month=22, Predicted=8.529130, Expected=9.819700
# Month=23, Predicted=9.275977, Expected=9.827300
# Month=24, Predicted=10.144330, Expected=9.929800
# Month=25, Predicted=9.657823, Expected=9.288000
# Month=26, Predicted=9.775375, Expected=9.300000
# Month=27, Predicted=9.311467, Expected=9.060000
# Month=28, Predicted=9.078285, Expected=8.835000
# Month=29, Predicted=8.935980, Expected=8.388600
# Month=30, Predicted=8.578898, Expected=8.400000
# Month=31, Predicted=8.448552, Expected=8.525000
# Month=32, Predicted=8.230215, Expected=8.250000
# Month=33, Predicted=8.264354, Expected=8.419000
# Month=34, Predicted=8.425667, Expected=9.455000
# Month=35, Predicted=8.840067, Expected=8.540000
# Month=36, Predicted=9.025447, Expected=9.455000
# Month=37, Predicted=8.955951, Expected=9.000000
# Month=38, Predicted=9.440999, Expected=9.599000
# Month=39, Predicted=9.334398, Expected=9.436000
# Month=40, Predicted=9.513213, Expected=9.539800
# Month=41, Predicted=9.496226, Expected=9.028600
# Month=42, Predicted=9.345210, Expected=8.932000
# Month=43, Predicted=8.998167, Expected=8.993000
# Month=44, Predicted=8.893002, Expected=8.678400
# Month=45, Predicted=8.755186, Expected=9.011100
# Month=46, Predicted=8.957583, Expected=9.630000
# Month=47, Predicted=8.587634, Expected=8.590400
# Month=48, Predicted=9.463096, Expected=9.736300
# Month=49, Predicted=9.227819, Expected=9.384500
# Month=50, Predicted=10.099127, Expected=9.947200
# Month=51, Predicted=9.742102, Expected=9.577100
# Month=52, Predicted=9.989867, Expected=9.117200
# Month=53, Predicted=9.285400, Expected=9.122500
# Month=54, Predicted=9.170269, Expected=8.880000
# Month=55, Predicted=8.903917, Expected=8.709200
# Month=56, Predicted=8.793932, Expected=8.428200
# Month=57, Predicted=8.539005, Expected=9.907600
# Month=58, Predicted=8.823597, Expected=9.145000
# Month=59, Predicted=8.726314, Expected=8.498000
# Month=60, Predicted=8.677053, Expected=9.362000
# Month=61, Predicted=8.881364, Expected=9.000000
# Month=62, Predicted=9.332684, Expected=9.455000
# Month=63, Predicted=9.323000, Expected=9.300000
# Month=64, Predicted=9.423701, Expected=8.990000
# Month=65, Predicted=9.113289, Expected=8.990000
# Month=66, Predicted=9.048350, Expected=8.790000
# Month=67, Predicted=8.778010, Expected=8.835000
# Month=68, Predicted=8.839120, Expected=8.700000
# Month=69, Predicted=8.594236, Expected=8.935000
# Month=70, Predicted=8.817903, Expected=8.835000
# Month=71, Predicted=8.596955, Expected=8.265000
# Month=72, Predicted=8.571187, Expected=8.835000
# Month=73, Predicted=8.551498, Expected=8.550000
# Month=74, Predicted=8.838242, Expected=8.680000
# Month=75, Predicted=8.700690, Expected=8.400000
# Month=76, Predicted=8.420006, Expected=8.525000
# Month=77, Predicted=8.545883, Expected=8.370000
# Month=78, Predicted=8.231786, Expected=7.890000
# Month=79, Predicted=8.113761, Expected=7.812000
# Month=80, Predicted=7.878479, Expected=7.620000
# Month=81, Predicted=7.647173, Expected=7.718000
# Month=82, Predicted=7.701271, Expected=8.323500
# Month=83, Predicted=7.624550, Expected=6.860000
# Month=84, Predicted=8.333421, Expected=8.308000
# Month=85, Predicted=7.992394, Expected=8.100000
# Month=86, Predicted=8.503477, Expected=8.525000
# Month=87, Predicted=8.404595, Expected=8.250000
# Month=88, Predicted=8.536816, Expected=8.215000
# Month=89, Predicted=8.274084, Expected=8.122600
# Month=90, Predicted=8.048936, Expected=7.778100
# Month=91, Predicted=7.914967, Expected=7.954600
# Month=92, Predicted=7.965547, Expected=7.420000
# Month=93, Predicted=7.809425, Expected=7.538300
# Month=94, Predicted=7.530444, Expected=7.905000
# Month=95, Predicted=7.224666, Expected=7.140000
# Month=96, Predicted=8.201429, Expected=8.432000
# Month=97, Predicted=7.778427, Expected=7.710000
# Month=98, Predicted=8.158957, Expected=7.967000
# Month=99, Predicted=7.845539, Expected=7.320000
# Month=100, Predicted=7.979076, Expected=7.502000
# Month=101, Predicted=7.437221, Expected=7.409000
# Month=102, Predicted=7.163480, Expected=7.200600
# Month=103, Predicted=7.246040, Expected=7.865000
# Month=104, Predicted=7.601308, Expected=6.690000
# Month=105, Predicted=7.337717, Expected=6.879400
# Month=106, Predicted=6.886318, Expected=7.440000
# Month=107, Predicted=6.531185, Expected=6.860000
# Month=108, Predicted=7.545080, Expected=7.595000
# Month=109, Predicted=7.198595, Expected=7.200000
# Month=110, Predicted=7.289047, Expected=7.130000
# Month=111, Predicted=7.205614, Expected=6.900000
# Month=112, Predicted=6.949369, Expected=7.130000
# Month=113, Predicted=7.099580, Expected=7.130000
# Month=114, Predicted=6.740706, Expected=6.840000
# Month=115, Predicted=6.910354, Expected=7.006000
# Month=116, Predicted=7.017016, Expected=6.780000
# Month=117, Predicted=6.722994, Expected=7.089600
# Month=118, Predicted=7.028454, Expected=6.882000
# Month=119, Predicted=6.873590, Expected=6.446700
# Month=120, Predicted=6.634489, Expected=6.882000
# Month=121, Predicted=6.740304, Expected=6.600000
# Month=122, Predicted=6.913345, Expected=6.820000
# Month=123, Predicted=6.811509, Expected=6.600000
# Month=124, Predicted=6.540677, Expected=6.820000
# Month=125, Predicted=6.787183, Expected=6.665000
# Month=126, Predicted=6.507292, Expected=6.450000
# Month=127, Predicted=6.524584, Expected=6.665000
# Month=128, Predicted=6.630653, Expected=6.450000
# Month=129, Predicted=6.381523, Expected=6.722100
# Month=130, Predicted=6.668781, Expected=6.820000
# Month=131, Predicted=6.288018, Expected=6.160000
# Month=132, Predicted=6.668159, Expected=6.820000
# Month=133, Predicted=6.451124, Expected=6.480000
# Month=134, Predicted=6.596733, Expected=6.596900
# Month=135, Predicted=6.627245, Expected=6.492000
# Month=136, Predicted=6.296844, Expected=6.510000
# Month=137, Predicted=6.439457, Expected=6.339500
# Month=138, Predicted=6.288632, Expected=6.001600
# Month=139, Predicted=6.141215, Expected=6.107000
# Month=140, Predicted=6.140715, Expected=5.790000
# Month=141, Predicted=5.860651, Expected=5.885000
# Month=142, Predicted=5.920558, Expected=7.280000
# Month=143, Predicted=6.594353, Expected=5.941600
# Month=144, Predicted=6.430975, Expected=6.810000
# Month=145, Predicted=6.400938, Expected=6.182000
# Month=146, Predicted=6.513171, Expected=6.293000
# Month=147, Predicted=6.266128, Expected=6.118600
# Month=148, Predicted=6.011779, Expected=6.138000
# Month=149, Predicted=6.131124, Expected=6.107000
# Month=150, Predicted=5.927902, Expected=5.913000
# Month=151, Predicted=5.914713, Expected=6.141100
# Month=152, Predicted=6.087507, Expected=6.248000
# Month=153, Predicted=5.704417, Expected=5.829700
# Month=154, Predicted=6.027835, Expected=6.829300
# Month=155, Predicted=6.269357, Expected=6.694400
# Month=156, Predicted=7.272080, Expected=7.726200
# Month=157, Predicted=7.169714, Expected=7.054400
# Month=158, Predicted=7.595147, Expected=7.268900
# Month=159, Predicted=7.181549, Expected=7.020000
# Month=160, Predicted=7.002531, Expected=6.510000
# Month=161, Predicted=6.725221, Expected=6.370500
# Month=162, Predicted=6.447640, Expected=5.730000
# Month=163, Predicted=6.071230, Expected=5.828000
# Month=164, Predicted=5.804520, Expected=5.580000
# Month=165, Predicted=5.568128, Expected=5.709900
# Month=166, Predicted=5.718393, Expected=6.696000
# Month=167, Predicted=6.107507, Expected=6.248000
# Month=168, Predicted=6.809624, Expected=6.711600
# Month=169, Predicted=6.546433, Expected=6.600100
# Month=170, Predicted=6.660657, Expected=7.508200
# Month=171, Predicted=7.067223, Expected=7.765000
# Month=172, Predicted=7.368758, Expected=7.285000
# Month=173, Predicted=7.665611, Expected=6.959500
# Month=174, Predicted=7.081417, Expected=6.450000
# Month=175, Predicted=6.644081, Expected=6.572000
# Month=176, Predicted=6.569363, Expected=6.600000
# Month=177, Predicted=6.241272, Expected=4.265300
# Month=178, Predicted=7.320985, Expected=7.367000
# Month=179, Predicted=6.528470, Expected=6.544000
# Month=180, Predicted=6.851619, Expected=6.940800
# Train RMSE: 0.40770
# Train RMSPE: 5.96041
# Train MAE: 0.28653
# Train MAPE: 3.79769
# Forecasting Testing Data
# Month=1, Predicted=6.713063, Expected=6.786000
# Month=2, Predicted=6.820202, Expected=6.981200
# Month=3, Predicted=6.900413, Expected=6.756000
# Month=4, Predicted=6.698495, Expected=6.733200
# Month=5, Predicted=6.770496, Expected=6.671200
# Month=6, Predicted=6.563074, Expected=6.295600
# Month=7, Predicted=6.453051, Expected=6.432500
# Month=8, Predicted=6.454255, Expected=6.153000
# Month=9, Predicted=6.171457, Expected=6.389500
# Month=10, Predicted=6.374559, Expected=7.192000
# Month=11, Predicted=6.263887, Expected=6.524000
# Month=12, Predicted=6.739524, Expected=7.238500
# Month=13, Predicted=6.835340, Expected=6.990000
# Month=14, Predicted=6.999754, Expected=7.254000
# Month=15, Predicted=7.220023, Expected=6.720000
# Month=16, Predicted=7.199137, Expected=6.944000
# Month=17, Predicted=6.889214, Expected=7.052500
# Month=18, Predicted=6.508168, Expected=6.690000
# Month=19, Predicted=6.817440, Expected=6.909900
# Month=20, Predicted=6.902874, Expected=6.819000
# Month=21, Predicted=6.565111, Expected=7.167200
# Month=22, Predicted=6.947907, Expected=7.254000
# Month=23, Predicted=6.799993, Expected=6.664000
# Month=24, Predicted=7.073851, Expected=7.393500
# Month=25, Predicted=6.998269, Expected=7.125000
# Month=26, Predicted=7.154910, Expected=7.347000
# Month=27, Predicted=7.334585, Expected=7.216500
# Month=28, Predicted=7.022222, Expected=7.254000
# Month=29, Predicted=7.201538, Expected=7.238500
# Month=30, Predicted=7.024330, Expected=6.990000
# Month=31, Predicted=7.029141, Expected=7.192000
# Month=32, Predicted=7.179348, Expected=6.900000
# Month=33, Predicted=6.942770, Expected=7.427300
# Month=34, Predicted=7.259228, Expected=7.300500
# Month=35, Predicted=7.417137, Expected=6.902000
# Month=36, Predicted=7.077012, Expected=7.409000
# Month=37, Predicted=7.230714, Expected=7.179000
# Month=38, Predicted=7.459210, Expected=7.424500
# Month=39, Predicted=7.388870, Expected=7.275000
# Month=40, Predicted=7.117122, Expected=7.316000
# Month=41, Predicted=7.280627, Expected=7.086300
# Month=42, Predicted=7.079656, Expected=7.020000
# Month=43, Predicted=7.071003, Expected=7.270500
# Month=44, Predicted=7.042171, Expected=7.168800
# Month=45, Predicted=6.938365, Expected=7.448600
# Month=46, Predicted=7.269180, Expected=7.440200
# Test RMSE: 0.27964
# Test RMSPE: 3.95206
# Test MAE: 0.22090
# Test MAPE: 3.13824
